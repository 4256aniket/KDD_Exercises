# %% [markdown]
# # Exercise 1: Getting to Know Your Data
#
# For this exercise, we require a series of libraries. They are imported by executing the following code cell.

# %%
# !pip install -r requirements.txt
# Out:
# Collecting scipy==1.14.0 (from -r requirements.txt (line 1))
#   Downloading scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting pandas==2.2.2 (from -r requirements.txt (line 2))
#   Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting scikit-learn==1.5.0 (from -r requirements.txt (line 3))
#   Downloading scikit_learn-1.5.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 4))
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting squarify==0.4.3 (from -r requirements.txt (line 5))
#   Downloading squarify-0.4.3-py3-none-any.whl.metadata (540 bytes)
# Requirement already satisfied: pywaffle==1.1.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.1.1)
# Collecting matplotlib==3.9.0 (from -r requirements.txt (line 7))
#   Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting plotly==5.22.0 (from -r requirements.txt (line 8))
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: seaborn==0.13.2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.13.2)
# Collecting ipython==8.26.0 (from -r requirements.txt (line 11))
#   Downloading ipython-8.26.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: jupyterlab==4.2.5 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (4.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from scikit-learn==1.5.0->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from scikit-learn==1.5.0->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: fontawesomefree in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from pywaffle==1.1.1->-r requirements.txt (line 6)) (6.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from matplotlib==3.9.0->-r requirements.txt (line 7)) (3.1.4)
# Collecting tenacity>=6.2.0 (from plotly==5.22.0->-r requirements.txt (line 8))
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (2.18.0)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipython==8.26.0->-r requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.27.2)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (3.1.4)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (75.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 12)) (6.4.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (4.6.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.0.6)
# Requirement already satisfied: idna in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.8.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (8.6.3)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (26.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jedi>=0.16->ipython==8.26.0->-r requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-core->jupyterlab==4.2.5->-r requirements.txt (line 12)) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from pexpect>4.3->ipython==8.26.0->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython==8.26.0->-r requirements.txt (line 11)) (0.2.13)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from stack-data->ipython==8.26.0->-r requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from stack-data->ipython==8.26.0->-r requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from stack-data->ipython==8.26.0->-r requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.6)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/ds/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 12)) (2.9.0.20241003)
# Downloading scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 29.2 MB/s eta 0:00:0031m30.2 MB/s eta 0:00:01
# Downloading pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 30.5 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading scikit_learn-1.5.0-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 31.3 MB/s eta 0:00:001m32.0 MB/s eta 0:00:01
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 27.3 MB/s eta 0:00:0031m27.8 MB/s eta 0:00:01
# Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 30.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 32.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading ipython-8.26.0-py3-none-any.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.9/817.9 kB 24.9 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Installing collected packages: squarify, tenacity, numpy, scipy, plotly, pandas, scikit-learn, matplotlib, ipython
#   Attempting uninstall: squarify
#     Found existing installation: squarify 0.4.4
#     Uninstalling squarify-0.4.4:
#       Successfully uninstalled squarify-0.4.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.1
#     Uninstalling numpy-2.1.1:
#       Successfully uninstalled numpy-2.1.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.0.1
#     Uninstalling plotly-6.0.1:
#       Successfully uninstalled plotly-6.0.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.2
#     Uninstalling matplotlib-3.9.2:
#       Successfully uninstalled matplotlib-3.9.2
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.28.0
#     Uninstalling ipython-8.28.0:
#       Successfully uninstalled ipython-8.28.0
# Successfully installed ipython-8.26.0 matplotlib-3.9.0 numpy-1.26.4 pandas-2.2.2 plotly-5.22.0 scikit-learn-1.5.0 scipy-1.14.0 squarify-0.4.3 tenacity-9.1.2

# %%
# Import required libraries
import os
import tempfile
import sqlite3
import urllib.request
import squarify
import pywaffle
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %% [markdown]
# In addition to the libraries, we also need data with which we can familiarize ourselves during the exercise. For this purpose, we use the so-called AdventureWorks database, which is modeled after a fictional shop.
#
# The following code cells download the database from GitHub (first cell) and then import the data required for this exercise into a pandas `DataFrame` (second cell).

# %%
# Create a temporary directory
dataset_folder = tempfile.mkdtemp()

# Build path to database
database_path = os.path.join(dataset_folder, "adventure-works.db")

# Get the database
urllib.request.urlretrieve(
    "https://github.com/FAU-CS6/KDD-Databases/raw/main/AdventureWorks/adventure-works.db",
    database_path,
)

# Open connection to the adventure-works.db
connection = sqlite3.connect(database_path)

# %%
# Create the clean DataFrame(s)
# Order DataFrame
order_df = pd.read_sql_query(
    "SELECT p.ProductID,p.Name,p.ProductNumber,p.MakeFlag,p.FinishedGoodsFlag,p.Color,p.SafetyStockLevel,"
    "p.ReorderPoint,p.StandardCost,p.ListPrice,p.Size,p.SizeUnitMeasureCode,p.WeightUnitMeasureCode,p.Weight,"
    "p.DaysToManufacture,p.ProductLine,p.Class,p.Style,p.ProductSubcategoryID,p.ProductModelID,p.SellStartDate,"
    "p.SellEndDate,p.DiscontinuedDate,d.PurchaseOrderID,d.PurchaseOrderDetailID,d.DueDate,d.OrderQty,d.ProductID,"
    "d.UnitPrice,d.ReceivedQty,d.RejectedQty,h.RevisionNumber,h.Status,h.EmployeeID,h.VendorID,h.ShipMethodID,"
    "h.OrderDate,h.ShipDate,h.SubTotal,h.TaxAmt,h.Freight,h.TotalDue,e.NationalIDNumber,e.LoginID,e.OrganizationNode,"
    "e.JobTitle,e.BirthDate,e.MaritalStatus,e.Gender,e.HireDate,e.SalariedFlag,e.VacationHours,e.SickLeaveHours,"
    "e.CurrentFlag,r.PersonType,r.NameStyle,r.Title,r.FirstName,r.MiddleName,r.LastName,r.Suffix,r.EmailPromotion,"
    "r.AdditionalContactInfo,r.Demographics "
    "FROM Product p "
    "JOIN PurchaseOrderDetail d ON p.ProductID = d.ProductID "
    "JOIN PurchaseOrderHeader h ON d.PurchaseOrderID = h.PurchaseOrderID "
    "JOIN Employee e ON h.EmployeeID = e.BusinessEntityID "
    "JOIN Person r ON e.BusinessEntityID = r.BusinessEntityID",
    connection,
    index_col="PurchaseOrderDetailID",
)

# %% [markdown]
# Currently we don't know anything about the `DataFrame` `order_df`.
# In order to gather an initial understanding of the structure of the `DataFrame`, it is useful to know the dimensions of the `DataFrame`. The corresponding information is stored in the shape property of a pandas `DataFrame`.
#
# <div class="alert alert-block alert-info">
#
# **Task 1:**
#
# Figure out the shape of `order_df`. You may take a look at the [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html) regarding the mentioned property.
#
# </div>

# %%
# Get the shape of the DataFrame
order_df.shape
# Out:
# (8845, 63)

# %% [markdown]
# The output of shape is a tuple containing two values. It is of course important to know which number is the number of attributes and which is the number tuples/samples in our `DataFrame`.
#
# <div class="alert alert-block alert-info">
#
# **Task 2:**
#
# Take a look at the documentation to determine which element stands for the number of attributes and which for the number of tuples.
#
# </div>

# %% [markdown]
# The count of attributes/features: ?
#
# The count of tuples/samples: ?

# %% [markdown]
# Now that we know the count of tuples and attributes in our `DataFrame`, we still do not know what data is contained in the data set.
#
# In order to get a first impression in this respect, it can be useful to look at (a sample of) the `DataFrame`. The supposedly simplest method to make this possible is the `print()` function.

# %%
# Print the order_df
print(order_df)
# Out:
#                        ProductID                             Name  \
# PurchaseOrderDetailID
# 1                              1                  Adjustable Race
# 2                            359               Thin-Jam Hex Nut 9
# 3                            360              Thin-Jam Hex Nut 10
# 4                            530                        Seat Post
# 5                              4            Headset Ball Bearings
# ...                          ...                              ...
# 8841                         880          Hydration Pack - 70 oz.
# 8842                         881   Short-Sleeve Classic Jersey, S
# 8843                         882   Short-Sleeve Classic Jersey, M
# 8844                         883   Short-Sleeve Classic Jersey, L
# 8845                         884  Short-Sleeve Classic Jersey, XL
#
#                       ProductNumber  MakeFlag  FinishedGoodsFlag   Color  \
# PurchaseOrderDetailID
# 1                           AR-5381         0                  0    None
# 2                           HJ-1213         0                  0    None
# 3                           HJ-1220         0                  0    None
# 4                           SP-2981         0                  0    None
# 5                           BE-2908         0                  0    None
# ...                             ...       ...                ...     ...
# 8841                     HY-1023-70         0                  1  Silver
# 8842                      SJ-0194-S         0                  1  Yellow
# 8843                      SJ-0194-M         0                  1  Yellow
# 8844                      SJ-0194-L         0                  1  Yellow
# 8845                      SJ-0194-X         0                  1  Yellow
#
#                        SafetyStockLevel  ReorderPoint  StandardCost  \
# PurchaseOrderDetailID
# 1                                  1000           750        0.0000
# 2                                  1000           750        0.0000
# 3                                  1000           750        0.0000
# 4                                   500           375        0.0000
# 5                                   800           600        0.0000
# ...                                 ...           ...           ...
# 8841                                  4             3       20.5663
# 8842                                  4             3       41.5723
# 8843                                  4             3       41.5723
# 8844                                  4             3       41.5723
# 8845                                  4             3       41.5723
#
#                        ListPrice  ... PersonType NameStyle Title  FirstName  \
# PurchaseOrderDetailID             ...
# 1                           0.00  ...         EM         0  None       Erin
# 2                           0.00  ...         EM         0  None     Fukiko
# 3                           0.00  ...         EM         0  None     Fukiko
# 4                           0.00  ...         EM         0  None       Eric
# 5                           0.00  ...         EM         0  None    Reinout
# ...                          ...  ...        ...       ...   ...        ...
# 8841                       54.99  ...         EM         0  None     Fukiko
# 8842                       53.99  ...         EM         0  None     Fukiko
# 8843                       53.99  ...         EM         0  None     Fukiko
# 8844                       53.99  ...         EM         0  None     Fukiko
# 8845                       53.99  ...         EM         0  None     Fukiko
#
#                        MiddleName  LastName Suffix EmailPromotion  \
# PurchaseOrderDetailID
# 1                               M    Hagens   None              0
# 2                               J     Ogisu   None              0
# 3                               J     Ogisu   None              0
# 4                               S    Kurjan   None              2
# 5                               N  Hillmann   None              2
# ...                           ...       ...    ...            ...
# 8841                            J     Ogisu   None              0
# 8842                            J     Ogisu   None              0
# 8843                            J     Ogisu   None              0
# 8844                            J     Ogisu   None              0
# 8845                            J     Ogisu   None              0
#
#                        AdditionalContactInfo  \
# PurchaseOrderDetailID
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# ...                                      ...
# 8841                                    None
# 8842                                    None
# 8843                                    None
# 8844                                    None
# 8845                                    None
#
#                                                             Demographics
# PurchaseOrderDetailID
# 1                      <IndividualSurvey xmlns="http://schemas.micros...
# 2                      <IndividualSurvey xmlns="http://schemas.micros...
# 3                      <IndividualSurvey xmlns="http://schemas.micros...
# 4                      <IndividualSurvey xmlns="http://schemas.micros...
# 5                      <IndividualSurvey xmlns="http://schemas.micros...
# ...                                                                  ...
# 8841                   <IndividualSurvey xmlns="http://schemas.micros...
# 8842                   <IndividualSurvey xmlns="http://schemas.micros...
# 8843                   <IndividualSurvey xmlns="http://schemas.micros...
# 8844                   <IndividualSurvey xmlns="http://schemas.micros...
# 8845                   <IndividualSurvey xmlns="http://schemas.micros...
#
# [8845 rows x 63 columns]

# %% [markdown]
# However, as you can see, this method outputs the entire content of the `DataFrame` without any specific layout. This can cause problems, especially with very large `DataFrames` and is therefore not recommended. It is far more common to use the `DataFrame` member function `head()`.
#
# <div class="alert alert-block alert-info">
#
# **Task 3:**
#
# Use the pandas documentation to familiarize yourself with `head()`, then apply it to the `order_df` to display the first 10 tuples.
#
# </div>

# %%
# Use the head() function on the order_df while setting the number of rows displayed to 10
order_df.head(10)
# Out:
#                        ProductID                   Name ProductNumber  \
# PurchaseOrderDetailID
# 1                              1        Adjustable Race       AR-5381
# 2                            359     Thin-Jam Hex Nut 9       HJ-1213
# 3                            360    Thin-Jam Hex Nut 10       HJ-1220
# 4                            530              Seat Post       SP-2981
# 5                              4  Headset Ball Bearings       BE-2908
# 6                            512            HL Road Rim       RM-R800
# 7                            513            Touring Rim       RM-T801
# 8                            317            LL Crankarm       CA-5965
# 9                            318            ML Crankarm       CA-6738
# 10                           319            HL Crankarm       CA-7457
#
#                        MakeFlag  FinishedGoodsFlag  Color  SafetyStockLevel  \
# PurchaseOrderDetailID
# 1                             0                  0   None              1000
# 2                             0                  0   None              1000
# 3                             0                  0   None              1000
# 4                             0                  0   None               500
# 5                             0                  0   None               800
# 6                             0                  0   None               800
# 7                             0                  0   None               800
# 8                             0                  0  Black               500
# 9                             0                  0  Black               500
# 10                            0                  0  Black               500
#
#                        ReorderPoint  StandardCost  ListPrice  ... PersonType  \
# PurchaseOrderDetailID                                         ...
# 1                               750           0.0        0.0  ...         EM
# 2                               750           0.0        0.0  ...         EM
# 3                               750           0.0        0.0  ...         EM
# 4                               375           0.0        0.0  ...         EM
# 5                               600           0.0        0.0  ...         EM
# 6                               600           0.0        0.0  ...         EM
# 7                               600           0.0        0.0  ...         EM
# 8                               375           0.0        0.0  ...         EM
# 9                               375           0.0        0.0  ...         EM
# 10                              375           0.0        0.0  ...         EM
#
#                       NameStyle Title  FirstName  MiddleName  LastName Suffix  \
# PurchaseOrderDetailID
# 1                             0  None       Erin           M    Hagens   None
# 2                             0  None     Fukiko           J     Ogisu   None
# 3                             0  None     Fukiko           J     Ogisu   None
# 4                             0  None       Eric           S    Kurjan   None
# 5                             0  None    Reinout           N  Hillmann   None
# 6                             0  None     Mikael           Q  Sandberg   None
# 7                             0  None      Linda           P   Meisner   None
# 8                             0  None     Gordon           L       Hee   None
# 9                             0  None     Gordon           L       Hee   None
# 10                            0  None     Gordon           L       Hee   None
#
#                       EmailPromotion  AdditionalContactInfo  \
# PurchaseOrderDetailID
# 1                                  0                   None
# 2                                  0                   None
# 3                                  0                   None
# 4                                  2                   None
# 5                                  2                   None
# 6                                  2                   None
# 7                                  0                   None
# 8                                  0                   None
# 9                                  0                   None
# 10                                 0                   None
#
#                                                             Demographics
# PurchaseOrderDetailID
# 1                      <IndividualSurvey xmlns="http://schemas.micros...
# 2                      <IndividualSurvey xmlns="http://schemas.micros...
# 3                      <IndividualSurvey xmlns="http://schemas.micros...
# 4                      <IndividualSurvey xmlns="http://schemas.micros...
# 5                      <IndividualSurvey xmlns="http://schemas.micros...
# 6                      <IndividualSurvey xmlns="http://schemas.micros...
# 7                      <IndividualSurvey xmlns="http://schemas.micros...
# 8                      <IndividualSurvey xmlns="http://schemas.micros...
# 9                      <IndividualSurvey xmlns="http://schemas.micros...
# 10                     <IndividualSurvey xmlns="http://schemas.micros...
#
# [10 rows x 63 columns]

# %% [markdown]
# As you can see, the representation by `head()` is easier to read. However, `head()` also has its limitations. For example, not all attributes are displayed when the number of attribute is large.
#
# <div class="alert alert-block alert-info">
#
# **Task 4:**
#
# List the names of all columns.
#
# </div>

# %%
# Output a list of all columns
list(order_df.columns)
# Out:
# ['ProductID',
#  'Name',
#  'ProductNumber',
#  'MakeFlag',
#  'FinishedGoodsFlag',
#  'Color',
#  'SafetyStockLevel',
#  'ReorderPoint',
#  'StandardCost',
#  'ListPrice',
#  'Size',
#  'SizeUnitMeasureCode',
#  'WeightUnitMeasureCode',
#  'Weight',
#  'DaysToManufacture',
#  'ProductLine',
#  'Class',
#  'Style',
#  'ProductSubcategoryID',
#  'ProductModelID',
#  'SellStartDate',
#  'SellEndDate',
#  'DiscontinuedDate',
#  'PurchaseOrderID',
#  'DueDate',
#  'OrderQty',
#  'ProductID',
#  'UnitPrice',
#  'ReceivedQty',
#  'RejectedQty',
#  'RevisionNumber',
#  'Status',
#  'EmployeeID',
#  'VendorID',
#  'ShipMethodID',
#  'OrderDate',
#  'ShipDate',
#  'SubTotal',
#  'TaxAmt',
#  'Freight',
#  'TotalDue',
#  'NationalIDNumber',
#  'LoginID',
#  'OrganizationNode',
#  'JobTitle',
#  'BirthDate',
#  'MaritalStatus',
#  'Gender',
#  'HireDate',
#  'SalariedFlag',
#  'VacationHours',
#  'SickLeaveHours',
#  'CurrentFlag',
#  'PersonType',
#  'NameStyle',
#  'Title',
#  'FirstName',
#  'MiddleName',
#  'LastName',
#  'Suffix',
#  'EmailPromotion',
#  'AdditionalContactInfo',
#  'Demographics']

# %% [markdown]
# For example, we did not see the columns `WeightUnitMeasureCode`, `Weight`, `DaysToManufacture`, `ProductLine`, `Class` and `Style` in the above execution of `head()`.
#
# <div class="alert alert-block alert-info">
#
# **Task 5:**
#
# Show the first 10 tuples of the attributes `WeightUnitMeasureCode`, `Weight`, `DaysToManufacture`, `ProductLine`, `Class` and `Style`.
#
# </div>

# %%
# Print the attributes WeightUnitMeasureCode, Weight, DaysToManufacture, ProductLine, Class
# and "Style" of the first ten attributes
order_df[["WeightUnitMeasureCode","Weight","DaysToManufacture","ProductLine","Class","Style"]].head(10)
# Out:
#                       WeightUnitMeasureCode  Weight  DaysToManufacture  \
# PurchaseOrderDetailID
# 1                                      None     NaN                  0
# 2                                      None     NaN                  0
# 3                                      None     NaN                  0
# 4                                      None     NaN                  0
# 5                                      None     NaN                  0
# 6                                       G     400.0                  0
# 7                                       G     460.0                  0
# 8                                      None     NaN                  0
# 9                                      None     NaN                  0
# 10                                     None     NaN                  0
#
#                       ProductLine Class Style
# PurchaseOrderDetailID
# 1                            None  None  None
# 2                            None  None  None
# 3                            None  None  None
# 4                            None  None  None
# 5                            None  None  None
# 6                            None  None  None
# 7                            None  None  None
# 8                            None    L   None
# 9                            None    M   None
# 10                           None  None  None

# %% [markdown]
# Of course, it is a pity that all the attribute values shown are `0` in the `DaysToManufacture` attribute and `None` in the `ProductLine` attribute. However, this does not mean that this is the case for the entire `DataFrame`.
#
# <div class="alert alert-block alert-info">
#
# **Task 6:**
#
# Save all with `DaysToManufacture` higher than 0 into a new `DataFrame` called `order_dtm_not_zero_dataframe`.
#
# </div>

# %%
# Select all tuples with DaysToManufacture > 0
order_dtm_not_zero_dataframe = order_df[order_df["DaysToManufacture"] > 0]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 7:**
#
# Display the columns `WeightUnitMeasureCode`, `Weight`, `DaysToManufacture`, `ProductLine`, `Class`, and `Style` of `order_dtm_not_zero_dataframe`. Limit the output to 10 tuples.
#
# </div>

# %%
# Print the attributes "WeightUnitMeasureCode", "Weight", "DaysToManufacture", "ProductLine", "Class"
# and "Style" of the first ten attributes of the new order_dtm_not_zero_dataframe
order_dtm_not_zero_dataframe[["WeightUnitMeasureCode","Weight","DaysToManufacture","ProductLine","Class","Style"]].head(10)
# Out:
#                       WeightUnitMeasureCode  Weight  DaysToManufacture  \
# PurchaseOrderDetailID
# 28                                     None     NaN                  1
# 42                                     None     NaN                  1
# 43                                     None     NaN                  1
# 44                                     None     NaN                  1
# 45                                     None     NaN                  1
# 46                                     None     NaN                  1
# 54                                      G     149.0                  1
# 67                                      G     218.0                  1
# 68                                      G     215.0                  1
# 85                                     None     NaN                  1
#
#                       ProductLine Class Style
# PurchaseOrderDetailID
# 28                             T   None  None
# 42                             M     L   None
# 43                             M     M   None
# 44                             M     H   None
# 45                             R     L   None
# 46                             T     M   None
# 54                             R     H   None
# 67                             M     L   None
# 68                             M     M   None
# 85                             M     L   None

# %% [markdown]
# In addition to simply outputting data from the `DataFrame`, it can also be useful to examine some basic statistical descriptors.
#
# In this case we will focus here on the attributes `ReorderPoint`, `DaysToManufacture`, and `UnitPrice`.

# %%
# Print the attributes "ReorderPoint", "DaysToManufacture", and "UnitPrice" of the first ten tuples
order_df[["ReorderPoint", "DaysToManufacture", "UnitPrice"]].head(10)
# Out:
#                        ReorderPoint  DaysToManufacture  UnitPrice
# PurchaseOrderDetailID
# 1                               750                  0    50.2600
# 2                               750                  0    45.1200
# 3                               750                  0    45.5805
# 4                               375                  0    16.0860
# 5                               600                  0    57.0255
# 6                               600                  0    37.0860
# 7                               600                  0    26.5965
# 8                               375                  0    27.0585
# 9                               375                  0    33.5790
# 10                              375                  0    46.0635

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 8:**
#
# Determine the mean for each of the three attributes and print it. (Help: [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html))
#
# </div>

# %%
# Output the mean of "ReorderPoint"
order_df["ReorderPoint"].mean()
# Out:
# 589.2929338609384

# %%
# Output the mean of "DaysToManufacture"
order_df["DaysToManufacture"].mean()
# Out:
# 0.1348784624081402

# %%
# Output the mean of "UnitPrice"
order_df["UnitPrice"].mean()
# Out:
# 34.74296411531939

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 9:**
#
# Determine the median for each of the three attributes and print it. (Help: [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.median.html))
#
# </div>

# %%
# Output the median of "ReorderPoint"
order_df["ReorderPoint"].median()
# Out:
# 750.0

# %%
# Output the median of "DaysToManufacture"
order_df["DaysToManufacture"].median()
# Out:
# 0.0

# %%
# Output the median of "UnitPrice"
order_df["UnitPrice"].median()
# Out:
# 39.2805

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 10:**
#
# Determine the minimum value for each of the three attributes and print it.
#
# </div>

# %%
# Output the min of "ReorderPoint"
order_df["ReorderPoint"].min()
# Out:
# 3

# %%
# Output the min of "DaysToManufacture"
order_df["DaysToManufacture"].min()
# Out:
# 0

# %%
# Output the min of "UnitPrice"
order_df["UnitPrice"].min()
# Out:
# 0.21

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 11:**
#
# Determine the maximum value for each of the three attributes and print it.
#
# </div>

# %%
# Output the max of "ReorderPoint"
order_df["ReorderPoint"].max()
# Out:
# 750

# %%
# Output the max of "DaysToManufacture"
order_df["DaysToManufacture"].max()
# Out:
# 1

# %%
# Output the max of "UnitPrice"
order_df["UnitPrice"].max()
# Out:
# 82.8345

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 12:**
#
# Determine the mode for each of the three attributes and print it.
#
# </div>

# %%
# Output the mode of "ReorderPoint"
order_df["ReorderPoint"].mode()
# Out:
# 0    750
# Name: ReorderPoint, dtype: int64

# %%
# Output the mode of "DaysToManufacture"
order_df["DaysToManufacture"].mode()
# Out:
# 0    0
# Name: DaysToManufacture, dtype: int64

# %%
# Output the mode of "UnitPrice"
order_df["UnitPrice"].mode()
# Out:
# 0    31.4895
# 1    48.2895
# Name: UnitPrice, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 13:**
#
# Determine the number of unique values for each of the three attributes and output it. (Help: Take a look at the function `nunique` in the pandas documentation.)
#
# </div>

# %%
# Output the nunique of "ReorderPoint"
order_df["ReorderPoint"].nunique()
# Out:
# 5

# %%
# Output the nunique of "DaysToManufacture"
order_df["DaysToManufacture"].nunique()
# Out:
# 2

# %%
# Output the nunique of "UnitPrice"
order_df["UnitPrice"].nunique()
# Out:
# 177

# %% [markdown]
# There are also methods in pandas that can be used to obtain multiple simple statistical values simultaneously for a `DataFrame`. An example is `describe`, which encapsulates the output of count, maximum, minimum, mean, standard deviation, and some quantiles in one function.
#
# <div class="alert alert-block alert-info">
#
# **Task 14:**
#
# Output the result for `describe` for each of the three attributes.
#
# </div>

# %%
# Output the result for describe of "ReorderPoint"
order_df["ReorderPoint"].describe()
# Out:
# count    8845.000000
# mean      589.292934
# std       199.114087
# min         3.000000
# 25%       375.000000
# 50%       750.000000
# 75%       750.000000
# max       750.000000
# Name: ReorderPoint, dtype: float64

# %%
# Output the result for describe of "DaysToManufacture"
order_df["DaysToManufacture"].describe()
# Out:
# count    8845.000000
# mean        0.134878
# std         0.341613
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: DaysToManufacture, dtype: float64

# %%
# Output the result for describe of "UnitPrice"
order_df["UnitPrice"].describe()
# Out:
# count    8845.000000
# mean       34.742964
# std        16.315439
# min         0.210000
# 25%        25.420500
# 50%        39.280500
# 75%        45.444000
# max        82.834500
# Name: UnitPrice, dtype: float64

# %% [markdown]
# Another method is `agg`, with the help of which several self-defined statistical values are calculated for a `DataFrame` in a single call.
#
# <div class="alert alert-block alert-info">
#
# **Task 15:**
#
# Output the mean, median, minimum, maximum, and number of unique values again for each of the three attributes. This time, use `agg`.
#
# </div>

# %%
# Output the result for agg of "ReorderPoint"
order_df["ReorderPoint"].agg(["mean","median","min","max","nunique"])
# Out:
# mean       589.292934
# median     750.000000
# min          3.000000
# max        750.000000
# nunique      5.000000
# Name: ReorderPoint, dtype: float64

# %%
# Output the result for agg of "DaysToManufacture"
order_df["DaysToManufacture"].agg(["mean","median","min","max","nunique"])
# Out:
# mean       0.134878
# median     0.000000
# min        0.000000
# max        1.000000
# nunique    2.000000
# Name: DaysToManufacture, dtype: float64

# %%
# Output the result for agg of "UnitPrice"
order_df["UnitPrice"].agg(["mean","median","min","max","nunique"])
# Out:
# mean        34.742964
# median      39.280500
# min          0.210000
# max         82.834500
# nunique    177.000000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# Even though the methods used here are fairly simple statistical methods, they can already tell us quite a bit about our data.
#
# <div class="alert alert-block alert-info">
#
# **Task 16:**
#
# Consider and describe what can be said about the attribute `ReorderPoint` based on the statistical values obtained.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 17:**
#
# Consider and describe what can be said about the `DaysToManufacture` attribute based on the statistical values obtained.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 18:**
#
# Consider and describe what can be said about the `UnitPrice` attribute based on the statistical values obtained.
# </div>

# %% [markdown]
# The distribution of the individual values within the attributes is something we can not specific with these simple statistical values. A possibility to get more information about this is a histogram.
#
# <div class="alert alert-block alert-info">
#
# **Task 19:**
#
# Draw a histogram for `ReorderPoint`. Consider what number of bins might be appropriate. (Help: [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html))
# </div>

# %%
# Histogram for "ReorderPoint"
plt.hist(order_df["ReorderPoint"],bins=20)
# Out:
# (array([  57.,  315.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#         2574.,    0.,    0.,    0.,    0.,    0., 1277.,    0.,    0.,
#            0., 4622.]),
#  array([  3.  ,  40.35,  77.7 , 115.05, 152.4 , 189.75, 227.1 , 264.45,
#         301.8 , 339.15, 376.5 , 413.85, 451.2 , 488.55, 525.9 , 563.25,
#         600.6 , 637.95, 675.3 , 712.65, 750.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 20:**
#
# Draw a histogram for `DaysToManufacture`. Consider what number of bins might be appropriate.
# </div>

# %%
# Histogram for "DaysToManufacture"
plt.hist(order_df["DaysToManufacture"],bins=2)
# Out:
# (array([7652., 1193.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 21:**
#
# Draw a histogram for `UnitPrice`. Consider what number of bins might be appropriate.
# </div>

# %%
# Histogram for "UnitPrice"
plt.hist(order_df["UnitPrice"],bins=40)
# Out:
# (array([228., 353., 270., 170., 182., 211., 155., 134.,   1., 102., 223.,
#         153., 177., 143., 307., 281., 259., 540., 633., 823., 873., 696.,
#         654., 570., 254.,  31.,   0.,  82.,  33.,   0., 207.,   0.,   0.,
#           0.,   0.,   0.,   0.,   0.,   0., 100.]),
#  array([ 0.21     ,  2.2756125,  4.341225 ,  6.4068375,  8.47245  ,
#         10.5380625, 12.603675 , 14.6692875, 16.7349   , 18.8005125,
#         20.866125 , 22.9317375, 24.99735  , 27.0629625, 29.128575 ,
#         31.1941875, 33.2598   , 35.3254125, 37.391025 , 39.4566375,
#         41.52225  , 43.5878625, 45.653475 , 47.7190875, 49.7847   ,
#         51.8503125, 53.915925 , 55.9815375, 58.04715  , 60.1127625,
#         62.178375 , 64.2439875, 66.3096   , 68.3752125, 70.440825 ,
#         72.5064375, 74.57205  , 76.6376625, 78.703275 , 80.7688875,
#         82.8345   ]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# It can be seen that it does not always make sense to choose the number of bins exactly like the number of unique values.
#
# Apart from that, we have to note that especially in the case of `UnitPrice`, insight is lost by merging multiple values. In such a case it can also be useful to look at boxplot and density curve instead of histogram.
#
# <div class="alert alert-block alert-info">
#
# **Task 22:**
#
# Draw a boxplot diagram for `UnitPrice`. (Help: [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.box.html))
# </div>

# %%
# Boxplot for "UnitPrice"
order_df["UnitPrice"].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 23:**
#
# Draw a density diagram for "UnitPrice". (Help: [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.density.html))
# </div>

# %%
# Density curve for "UnitPrice"
order_df["UnitPrice"].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# While simple chart types such as histograms, boxplots and density plots can be directly used with pandas, a variety of libraries are available for more advanced visualizations.

# %% [markdown]
# In the lecture you were introduced to Polar Plots, also called Radar Chart. In this type of chart, you look at multiple attributes of a single tuple.
#
# <div class="alert alert-block alert-info">
#
# **Task 24:**
#
# Use Plotly's graph function `Scatterpolar` to output the prepared tuples within one polar plot. (Help: [Plotly Documentation](https://plotly.com/python/radar-chart/) and [Plotly API Reference](https://plotly.com/python-api-reference/generated/plotly.graph_objects.scatterpolar.html?highlight=scatterpolar#module-plotly.graph_objects.scatterpolar))
# </div>

# %%
# Set the attributes to select
attributes = ["OrderQty", "ReceivedQty", "RejectedQty"]

# Prepare tuple_6, tuple_77, tuple_82
tuple_6 = pd.DataFrame(dict(r=order_df[attributes].iloc[6].values, theta=attributes))
tuple_77 = pd.DataFrame(dict(r=order_df[attributes].iloc[77].values, theta=attributes))
tuple_82 = pd.DataFrame(dict(r=order_df[attributes].iloc[82].values, theta=attributes))

# %%
# Draw a single polar diagram for tuple_6, tuple_77 and tuple_82
import plotly.graph_objects as go


fig =go.Figure()

fig.add_trace(go.Scatterpolar(
    r = tuple_6['r'],
    theta = tuple_6['theta'],
    mode = 'lines+markers',
    name = 'tuple_6',
    line=dict(color = 'skyblue')
         
))
fig.add_trace(go.Scatterpolar(
    r = tuple_77['r'],
    theta = tuple_77['theta'],
    mode = 'lines+markers',
    name = 'tuple_77',
    line=dict(color = 'black')
         
))
fig.add_trace(go.Scatterpolar(
    r = tuple_82['r'],
    theta = tuple_82['theta'],
    mode = 'lines+markers',
    name = 'tuple_82',
    line=dict(color='orange')
         
))

fig.show()

# %% [markdown]
# One type of graph that we did not yet consider are scatter plots.
#
# <div class="alert alert-block alert-info">
#
# **Task 25:**
#
# Use the internal pandas functions to create a scatter plot of the `OrderQty` and `ReceivedQty` attributes in `order_df`. (Help: [pandas Documentation](https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.DataFrame.plot.scatter.html))
# </div>

# %%
# Draw a scatter plot regarding "OrderQty" and "ReceivedQty"

# %% [markdown]
# Within a scatter plot, exactly two attributes are always displayed on different axes. In order to compare more than two attributes with each other, a scatter plot matrix is often used.
#
# <div class="alert alert-block alert-info">
#
# **Task 26:**
#
# Use seaborn to plot a pair plot that creates a scatter plot matrix of the attributes `OrderQty`, `ReceivedQty` and `RejectedQty` in `order_df`. (Help: [Seaborn Documentation](https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot))
# </div>

# %%
# Draw a scatter plot regarding "OrderQty", "ReceivedQty" and "RejectedQty"
sns.pairplot(order_df[["OrderQty", "ReceivedQty", "RejectedQty"]],diag_kind="kde")

# %% [markdown]
# Icon Based Diagrams are often used to show percentage relationships in an understandable way.
#
# For example, it can be used to highlight the gender distribution of employees working with our orders.

# %%
# Get unique employees
orders_per_employee_df = (
    order_df.groupby(["EmployeeID", "FirstName", "MiddleName", "LastName", "Gender"])
    .size()
    .reset_index(name="Orders")
)

# Sort the DataFrame
orders_per_employee_df.sort_values("Orders", ascending=False, inplace=True)

# Show the head of the orders_per_employee_df
orders_per_employee_df.head(15)

# %%
# Get the count of employees per gender
employees_per_gender_df = orders_per_employee_df.groupby(["Gender"]).size()

# Print the head of this new DataFrame
employees_per_gender_df

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 27:**
#
# Use PyWaffle to draw an icon diagram regarding the genders of the employees. (Help: [PyWaffle Documentation](https://pywaffle.readthedocs.io/en/latest/examples/plot_with_characters_or_icons.html))
# </div>

# %%
# Draw the icon diagram

# %% [markdown]
# Even better than by Icon Diagrams, distributions can be displayed using tree maps.
#
# For example, a tree map can be used to display the count of orders processed per employee.

# %%
# Print the head of orders_per_employee (again)
orders_per_employee_df.head(15)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 28:**
#
# Use Squarify to draw a tree map displaying the count of orders processed per employee. (Help: [Squarify Documentation](https://github.com/laserson/squarify#Usage))
# </div>

# %%
# Draw the tree map

# %% [markdown]
# In addition to data visualization, it can also be useful to determine the similarity of data.
#
# Data similarity refers to the distance between two data sets. There are many different methods to determine distances between different types of data.
#
# In this chapter, we will focus on the distance between numeric data. More specifically, here, we compare previously selected and created tuples, namely `tuple_77` and `tuple_82`.

# %%
tuple_77["r"]

# %%
tuple_82["r"]

# %% [markdown]
# One of the most commonly used methods for calculating the distance between numerical values is the Manhattan distance, also called the L1 norm or City Block. A corresponding function that calculates the appropriate distance can be implemented relatively quickly using a for-loop.

# %%
# Method to compute the Manhattan distance using a for-loop
def manhattan_distance(tuple_a, tuple_b):
    # We do not check for correct datatypes and same length of both tuples
    # However this should be done in a productive environment

    # Set the distance to 0
    distance = 0

    # Add the distance for each tuple
    for i in range(len(tuple_a)):
        difference = tuple_a[i] - tuple_b[i]
        absolute_difference = abs(difference)
        distance += absolute_difference

    # Return the distance
    return distance

# %% [markdown]
# In Python, however, one would normally take a more elegant approach and avoid the for-loop.

# %%
# "Pythonic" method to compute the Manhattan distance
def manhattan_distance(tuple_a, tuple_b):
    # We do not check for correct datatypes and same length of both tuples
    # However this should be done in a productive environment

    # Convert lists to pandas Series
    if isinstance(tuple_a, list):
        a = pd.Series(tuple_a)
    else:
        a = tuple_a.copy()
    if isinstance(tuple_b, list):
        b = pd.Series(tuple_b)
    else:
        b = tuple_b.copy()

    # Compute the manhattan distance with a simple formula
    return (abs(a - b)).sum()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 29:**
#
# Use the defined function to compute the Manhattan distance between `tuple_77` and `tuple_82`.
# </div>

# %%
# Use the defined function to compute the Manhattan distance between tuple_77 and tuple_82

# %% [markdown]
# A second common variant is the Euclidean distance, also called L2 norm.
#
# <div class="alert alert-block alert-info">
#
# **Task 30:**
#
# Complete the following source code to create a function to calculate the Euclidean distance and use it to calculate the Euclidean distance between `tuple_77` and `tuple_82`.
# </div>

# %%
# Method to compute the euclidean distance
def euclidean_distance(tuple_a, tuple_b):
    # ...
    return -1


# Use the defined function to compute the Euclidean distance between tuple_77 and tuple_82
# ...

# %% [markdown]
# Apparently, for `tuple_77` and `tuple_82`, the Manhattan distance and the Euclidean distance do not differ. But what about the following two lists?

# %%
# Lists to compare
list_1 = [550, 550, 82]
list_2 = [82, 550, 550]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 31:**
#
# Compute the Manhattan distance and the Euclidean distance between `list_1` and `list_2`.
# </div>

# %%
# Compute the manhattan distance

# %%
# Compute the euclidean distance

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# **Task 32:**
#
# Consider and explain why the distance measures did not differ for `tuple_77` and `tuple_82`, but did for `list_1` and `list_2`.
# </div>

# %% [markdown]
# Write down your solution here:

# %% [markdown]
# Both the Manhattan distance and the Euclidean distance are special forms of the Minkowski distance.
#
# <div class="alert alert-block alert-info">
#
# **Task 33:**
#
# Implement the Minkowski distance using the given code fragment. Use the resulting function to calculate the Manhattan distance and the Euclidean distance of list 1 and list 2 again.
# </div>

# %%
# Method to compute the minkowski distance
def minkowski_distance(tuple_a, tuple_b, h):
    # ...
    return -1


# Use the function to compute the Manhattan and the Euclidean distance between list_1 and list_2 and print them
# ...
